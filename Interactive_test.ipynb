# %% [markdown]
# Connected to Python 3.8.10

# %%
#test_debug

def triple_number(num):
    out = 3*num
    return out

a = 3
b = triple_number(a)
print(b)
# Out:
# 9

# %%
c = 4*b

# %%
c
# Out:
# 36

# %%
a = 3
b = triple_number(a)
print(b)
# Out:
# 9

# %%
a
# Out:
# 3

# %%
b
# Out:
# 9

# %% [markdown]
# Restarted Python 3.8.10

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/drdarby/Desktop/cape_mend_SM_LCS/Interactive_test.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/home/drdarby/Desktop/cape_mend_SM_LCS/Interactive_test.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> a
#
# NameError: name 'a' is not defined
