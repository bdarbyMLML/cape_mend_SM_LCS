# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import math
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import datetime as dt
# %matplotlib inline
import os
import sys
sys.path.append('./datatools/')
import datatools as tools

# %%
path_tohd = '../../../../../../media/drdarby/Elements/data/test_3d_data/month_CALSWOT/'
param = ['Theta','Salt','U','V']
direc = ['THETA','SALT','U','V']
month_num = 2
on_number=len(os.listdir(path_tohd+direc[1]+'_'+str(month_num)+'/'))
on_number
# Out:
# 720

# %%
417+108
# Out:
# 525

# %% [markdown]
# # Convert to netcdf (LLC4320 surface fields)

# %%
# get mounted surface data
data_path = '../../../../mnt/thesis_model_data/Data/LLC4320/norcal_surf/'
variables = ['Eta','Theta','Salt','U','V','W','oceTUAX','oceTAUY']
data_files, data_filepath = tools.get_data_paths_from_binary(data_path,variables[1])
len(data_filepath)
# Out:
# 9121

# %%
def convert_binary_to_nc(file_name,file_path, shape, dims_list, coords_list, name,time_in_name_location=None, output_filepath='./'):
    '''converts binary files to netcdf through xarray framework
    '''
    file = np.fromfile(file_path,'>f4')
    file = np.reshape(file, shape)
    if time_in_name_location!=None:
        time = [int(filename[time_in_name_location[0]:time_in_name_location[1]])]
    field = xr.DataArray(file,coords=coords_list,dims=dims_list).rename(name)
    field.to_netcdf(output_filepath)
    field.close()

# %%
def convert_itter_to_datetime(number,datetime_start,timestep,shift_itter=0):
    '''converts an itteration number to a datetime'''
    itter_dt = datetime.fromtimestamp(datetime_start.timestamp()+(int(number)+int(shift_itter))*timestep)
    return itter_dt

# %%
convert_itter_to_datetime(179712,datetime(2011,9,10),25)
# Out:
# datetime.datetime(2011, 11, 1, 0, 0)

# %%
output = '/media/drdarby/Elements/data/Thesis/LLC4320/nc_files/'+variables[0]+'/'

# %%
variables = ['Eta','Theta','Salt','U','V','W','oceTUAX','oceTAUY']

i0 = np.arange(672)
j0 = np.arange(1486)
dim = ['time','i','j']
location = (0,10)
for j in range(1,len(variables)-6):
    for i in range(8095,len(data_files)):
        time_itter=data_files[i][location[0]:location[1]]
        output = '/media/drdarby/Elements/data/Thesis/LLC4320/nc_files/'+variables[j]+'/'+variables[j]+'_'+time_itter+'.nc'
        time = [convert_itter_to_datetime(time_itter,datetime(2011,9,10),25)]
        shape = (len(time),len(i0),len(j0))
        cord = [time, i0, j0]

        convert_binary_to_nc(data_files[i],data_filepath[i],shape,dim,cord,variables[j],output_filepath=output)
#k = np.arange(90)

# %%
data_path='/media/drdarby/Elements/data/Thesis/LLC4320/nc_files/'
d,p = tools.get_data_paths_from_binary(data_path,'Eta',file_end='nc')
d , p
test = xr.open_dataset(p[0])
test
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, i: 672, j: 1486)
# Coordinates:
#   * time     (time) datetime64[ns] 2012-11-19T04:00:00
#   * i        (i) int64 0 1 2 3 4 5 6 7 8 ... 663 664 665 666 667 668 669 670 671
#   * j        (j) int64 0 1 2 3 4 5 6 7 ... 1479 1480 1481 1482 1483 1484 1485
# Data variables:
#     EtaN     (time, i, j) float32 ...

# %%
def convert_mitgcm_grid_to_nc(path_to_grid_files,dim_of_grid):
    grid_prefix = ['Depth','DXV','DYU','RAZ','YC','DXC','DYC','hFacC','XC','YG','DXG','DYG','RAC','XG']
    if type(dim_of_grid)==tuple:
        dimx, dimy = dim_of_grid[0], dim_of_grid[1]
    elif type(dim_of_grid)==str:
        dimx, dimy = dim_of_grid.split('_')[1].split('x')
    
    convert_binary_to_nc()

# %%
location = (0,1)
x, y = location[0], location[1]
# Out:
# 1

# %%
grid_files = 'Depth_672x1486 DXV_672x1486 DYU_672x1486 RAZ_672x1486 YC_672x1486 DXC_672x1486 DYC_672x1486 hFacC_672x1486x1 XC_672x1486 YG_672x1486 DXG_672x1486 DYG_672x1486 RAC_672x1486 XG_672x1486'
grid_ind = grid_files.split(' ')
grid_prefix = []
for i in grid_ind:
    grid_prefix.append(i.split('_')[0])

grid_prefix = ['Depth',
 'DXV',
 'DYU',
 'RAZ',
 'YC',
 'DXC',
 'DYC',
 'hFacC',
 'XC',
 'YG',
 'DXG',
 'DYG',
 'RAC',
 'XG']
# Out:
# ['Depth',
#  'DXV',
#  'DYU',
#  'RAZ',
#  'YC',
#  'DXC',
#  'DYC',
#  'hFacC',
#  'XC',
#  'YG',
#  'DXG',
#  'DYG',
#  'RAC',
#  'XG']

# %%
output = '/media/drdarby/Elements/data/Thesis/LLC4320/nc_files/Eta'
file_paths = []
for i in os.listdir(output):
    file_paths.append(output+'/'+i)

# %%
xr.open_mfdataset(file_paths)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 xr.open_mfdataset(file_paths)
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/backends/api.py:1038, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1035     open_ = open_dataset
#    1036     getattr_ = getattr
# -> 1038 datasets = [open_(p, **open_kwargs) for p in paths]
#    1039 closers = [getattr_(ds, "_close") for ds in datasets]
#    1040 if preprocess is not None:
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/backends/api.py:1038, in <listcomp>(.0)
#    1035     open_ = open_dataset
#    1036     getattr_ = getattr
# -> 1038 datasets = [open_(p, **open_kwargs) for p in paths]
#    1039 closers = [getattr_(ds, "_close") for ds in datasets]
#    1040 if preprocess is not None:
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/backends/api.py:547, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     544     kwargs.update(backend_kwargs)
#     546 if engine is None:
# --> 547     engine = plugins.guess_engine(filename_or_obj)
#     549 if from_array_kwargs is None:
#     550     from_array_kwargs = {}
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/backends/plugins.py:154, in guess_engine(store_spec)
#     152 for engine, backend in engines.items():
#     153     try:
# --> 154         if backend.guess_can_open(store_spec):
#     155             return engine
#     156     except PermissionError:
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:556, in NetCDF4BackendEntrypoint.guess_can_open(self, filename_or_obj)
#     554 if isinstance(filename_or_obj, str) and is_remote_uri(filename_or_obj):
#     555     return True
# --> 556 magic_number = try_read_magic_number_from_path(filename_or_obj)
#     557 if magic_number is not None:
#     558     # netcdf 3 or HDF5
#     559     return magic_number.startswith((b"CDF", b"\211HDF\r\n\032\n"))
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/core/utils.py:674, in try_read_magic_number_from_path(pathlike, count)
#     672 try:
#     673     with open(path, "rb") as f:
# --> 674         return read_magic_number_from_file(f, count)
#     675 except (FileNotFoundError, TypeError):
#     676     pass
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/core/utils.py:662, in read_magic_number_from_file(filename_or_obj, count)
#     660     if filename_or_obj.tell() != 0:
#     661         filename_or_obj.seek(0)
# --> 662     magic_number = filename_or_obj.read(count)
#     663     filename_or_obj.seek(0)
#     664 else:
#
# KeyboardInterrupt:
