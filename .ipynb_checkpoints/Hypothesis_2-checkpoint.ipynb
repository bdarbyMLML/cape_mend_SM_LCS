# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import requests  # HTTP library for Python
import bs4
import math
import xarray as xr
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import gsw
# %matplotlib inline
import os
import sys
import xmitgcm 
import xgcm
import pyproj
#import wget
#sys.path.append('../../ECCOv4-py/ECCOv4-py')
#import ecco_v4_py as ecco
import cmocean
sys.path.append('/home/drdarby/Desktop/cape_mend_SM_LCS/datatools')
from datatools import datatools as tools
#from moviepy.config import change_settings
#change_settings({"FFMPEG_BINARY": "/usr/bin/ffmpeg"})
#import moviepy.video.io.ImageSequenceClip 

from scipy.fft import fft, fftfreq
from scipy.signal import periodogram
from scipy.signal import welch
from scipy.stats import chi2
from datetime import timedelta
from scipy.interpolate import griddata
from tqdm.notebook import tqdm

# %%
cutout_path = '/media/drdarby/Elements/data/Thesis/LLC4320/nc_files/cutouts/'
path_tohd = '/media/drdarby/Elements/data/Thesis/LLC4320/'

# %%
path_tohd = '/media/drdarby/Elements/data/Thesis/LLC4320/nc_files/'
grid_path = '/home/drdarby/Desktop/cape_mend_SM_LCS/data/cape_mend_grid_llc4320.nc'
grid = xr.open_dataset(grid_path)
variables = ['Eta','Theta','Salt','U','V','W','oceTAUX','oceTAUY']
#taux_files, taux_filepaths = tools.get_data_paths_from_binary(path_tohd,variables[-2],file_end='nc')
#tauy_files, tauy_filepaths = tools.get_data_paths_from_binary(path_tohd,variables[-1],file_end='nc')

#tauxy = xr.open_mfdataset(taux_filepaths+tauy_filepaths)#.where(np.isfinite(land_mask))
#taux_masked = tauxy['oceTAUX'][:,:-1,:-1].where(np.isfinite(land_mask))

# %%
ridge_points = xr.open_dataset(cutout_path+'ridge_points_repelling_bad.nc')

# %%
ridge_points.where(ridge_points.isel(lon_lat=1)>40.3)
# Out:
# <xarray.Dataset>
# Dimensions:                (time: 1519, points: 8784, lon_lat: 2)
# Coordinates:
#   * points                 (points) int64 0 1 2 3 4 ... 8779 8780 8781 8782 8783
#   * lon_lat                (lon_lat) object 'lon' 'lat'
#   * time                   (time) datetime64[ns] 2011-11-01 ... 2012-11-14T12...
# Data variables:
#     attracting_structures  (time, points, lon_lat) float64 nan nan ... nan nan
#     repelling_structures   (time, points, lon_lat) float64 nan nan ... nan nan

# %%
ridge_counts_attracting = []
ridge_counts_repelling = []
for i in range(0,len(ridge_points.time)):
    lon_points_attr = ridge_points.isel(time=i,lon_lat=0)['attracting_structures'].dropna('points',how='all')
    #lat_points_attr = ridge_points.isel(time=i,lon_lat=1)['attracting_structures']
    lon_points_rep = ridge_points.isel(time=i,lon_lat=0)['repelling_structures'].dropna('points',how='all')
    ridge_counts_attracting.append(len(lon_points_attr))
    ridge_counts_repelling.append(len(lon_points_rep))
    #lat_points_rep = ridge_points.isel(time=i,lon_lat=1)['repelling_structures']

# %%
plt.figure(figsize=(12,8))
plt.plot(ridge_points.time,ridge_counts_attracting,label='total attracting counts')
plt.plot(ridge_points.time,ridge_counts_repelling,label='total repelling counts')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Total LCS Points')
plt.savefig('./counts_of_LCS.png')

# %%
lcs_model = xr.open_dataset('/media/drdarby/Elements/data/Thesis/LLC4320/nc_files/cutouts/lcs_cape_mend_landmask.nc')

# %%
lcs_model_area_N = lcs_model.where(lcs_model.lat>40.7)
lcs_model_area_C = lcs_model.where(np.logical_and(lcs_model.lat<40.7,lcs_model.lat>40))
lcs_model_area_S = lcs_model.where(lcs_model.lat<40)

# %%
Area_norm_total = np.array(np.isfinite(lcs_model['ALCS'].isel(time=0)).sum())
Area_norm_N = np.array(np.isfinite(lcs_model_area_N['ALCS'].isel(time=0)).sum())
Area_norm_C = np.array(np.isfinite(lcs_model_area_C['ALCS'].isel(time=0)).sum())
Area_norm_S = np.array(np.isfinite(lcs_model_area_S['ALCS'].isel(time=0)).sum())

# %%
# Out:
# array(40873)

# %%
plt.close()
lcs_model_area_C.isel(time=0)['ALCS'].plot()

# %%
lcs_model_area['ALCS']

# %%
ridge_points_N = ridge_points.where(ridge_points.isel(lon_lat=1)>40.7)
ridge_points_C = ridge_points.where(np.logical_and(ridge_points.isel(lon_lat=1)>40,ridge_points.isel(lon_lat=1)<40.7))
ridge_points_S = ridge_points.where(ridge_points.isel(lon_lat=1)<40)

# %%
ridge_counts_attracting_N = []
ridge_counts_repelling_N = []
for i in range(0,len(ridge_points.time)):
    lon_points_attr = ridge_points_N.isel(time=i,lon_lat=0)['attracting_structures'].dropna('points',how='all')
    #lat_points_attr = ridge_points.isel(time=i,lon_lat=1)['attracting_structures']
    lon_points_rep = ridge_points_N.isel(time=i,lon_lat=0)['repelling_structures'].dropna('points',how='all')
    ridge_counts_attracting_N.append(len(lon_points_attr))
    ridge_counts_repelling_N.append(len(lon_points_rep))

# %%
ridge_counts_attracting_C = []
ridge_counts_repelling_C = []
for i in range(0,len(ridge_points.time)):
    lon_points_attr = ridge_points_C.isel(time=i,lon_lat=0)['attracting_structures'].dropna('points',how='all')
    #lat_points_attr = ridge_points.isel(time=i,lon_lat=1)['attracting_structures']
    lon_points_rep = ridge_points_C.isel(time=i,lon_lat=0)['repelling_structures'].dropna('points',how='all')
    ridge_counts_attracting_C.append(len(lon_points_attr))
    ridge_counts_repelling_C.append(len(lon_points_rep))

# %%
ridge_counts_attracting_S = []
ridge_counts_repelling_S = []
for i in range(0,len(ridge_points.time)):
    lon_points_attr = ridge_points_S.isel(time=i,lon_lat=0)['attracting_structures'].dropna('points',how='all')
    #lat_points_attr = ridge_points.isel(time=i,lon_lat=1)['attracting_structures']
    lon_points_rep = ridge_points_S.isel(time=i,lon_lat=0)['repelling_structures'].dropna('points',how='all')
    ridge_counts_attracting_S.append(len(lon_points_attr))
    ridge_counts_repelling_S.append(len(lon_points_rep))

# %%
fig,ax = plt.subplots(ncols=1, nrows=3,figsize=(26,8),sharex=True)

#plt.figure(figsize=(26,8))
ax[0].plot(ridge_points.time,ridge_counts_attracting_N/Area_norm_N,label='North attracting counts')
ax[0].plot(ridge_points.time,ridge_counts_attracting_C/Area_norm_C,label='Center attracting counts')
ax[0].plot(ridge_points.time,ridge_counts_attracting_S/Area_norm_S,label='South attracting counts')
ax[1].plot(ridge_points.time,ridge_counts_attracting/Area_norm_total,label='total attracting counts',color='black')
taux_masked.mean(dim='i',skipna=True).mean(dim='j',skipna=True).plot(label='cumulative sum',ax=ax[2])
ax[2].set_ylabel('surface wind stress N/m$^2$')
#plt.plot(ridge_points.time,ridge_counts_repelling_N,label='N repelling counts')
ax[0].legend()
plt.xlabel('Time')
ax[0].set_ylabel('normalized total LCS Points')
ax[1].set_ylabel('normalized total LCS Points')
# Out:
# Text(0, 0.5, 'normalized total LCS Points')

# %%
np.array(Area_norm_N)[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 Area_norm_N[0]
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/core/dataarray.py:822, in DataArray.__getitem__(self, key)
#     819     return self._getitem_coord(key)
#     820 else:
#     821     # xarray-style array indexing
# --> 822     return self.isel(indexers=self._item_key_to_dict(key))
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/core/dataarray.py:803, in DataArray._item_key_to_dict(self, key)
#     801 if utils.is_dict_like(key):
#     802     return key
# --> 803 key = indexing.expanded_indexer(key, self.ndim)
#     804 return dict(zip(self.dims, key))
#
# File ~/miniconda3/envs/mitgcm/lib/python3.11/site-packages/xarray/core/indexing.py:232, in expanded_indexer(key, ndim)
#     230         new_key.append(k)
#     231 if len(new_key) > ndim:
# ...

# %% [markdown]
# ### Case Study (eddy)
# - merge all the points and subselected properties into one datafile and then cut to case study points.
# - Need to run frontogenesis function then subselect.
# - Need to run flow imbalance function then subselect.

# %%
case_study_range_eddy = ['2012-07-05', '2012-08-31']
case_study_range_fil = ['2012-08-06', '2012-08-19']

# %%
cs_ridge_points=ridge_points.sel(time=slice(case_study_range_eddy[0],case_study_range_eddy[1]))

# %%
lon_cs_attr = cs_ridge_points.isel(lon_lat=0)['attracting_structures'].dropna('points',how='all')
lat_cs_attr = cs_ridge_points.isel(lon_lat=1)['attracting_structures'].dropna('points',how='all')
lon_cs_rep = cs_ridge_points.isel(lon_lat=0)['repelling_structures'].dropna('points',how='all')
lat_cs_rep = cs_ridge_points.isel(lon_lat=1)['repelling_structures'].dropna('points',how='all')

# %%
eddy_ridge_points=cs_ridge_points.where(np.logical_and(ridge_points.isel(lon_lat=1)>38.8,ridge_points.isel(lon_lat=1)<40.5))
eddy_ridge_points = eddy_ridge_points.where(np.logical_and(ridge_points.isel(lon_lat=0)>-125.5,ridge_points.isel(lon_lat=0)<-123.5))

lon_cs_attr_ed = eddy_ridge_points.isel(lon_lat=0)['attracting_structures'].dropna('points',how='all')
lat_cs_attr_ed = eddy_ridge_points.isel(lon_lat=1)['attracting_structures'].dropna('points',how='all')
lon_cs_rep_ed = eddy_ridge_points.isel(lon_lat=0)['repelling_structures'].dropna('points',how='all')
lat_cs_rep_ed = eddy_ridge_points.isel(lon_lat=1)['repelling_structures'].dropna('points',how='all')

# %%
#eddy_ridge_points=cs_ridge_points.where(np.logical_and(ridge_points.isel(lon_lat=1)>39,ridge_points.isel(lon_lat=1)<40.1))

for i in tqdm(range(0,len(lon_cs_rep_ed.time))):
#plt.plot(lon_cs_rep.isel(time=i),lat_cs_rep.isel(time=i),'.')
    plt.plot(lon_cs_attr_ed.isel(time=i),lat_cs_attr_ed.isel(time=i),'.',markersize=4,label='attracting points')

    plt.plot(lon_cs_rep_ed.isel(time=i),lat_cs_rep_ed.isel(time=i),'.',markersize=4,label='repelling points')
    plt.xlabel('Longitude')
    plt.legend(loc='upper right')
    plt.ylabel('Latitude')
    #plt.xticks(np.arange(-125.5, -123.8, step=0.2))
    #plt.yticks(np.arange(38.95, 40.5, step=0.30))
    plt.xlim([-125.5,-123.5])
    plt.ylim([38.8,40.5])
    plt.title(str(np.array(lon_cs_rep_ed.isel(time=i).time))[:10]+' '+str(np.array(lon_cs_rep_ed.isel(time=i).time))[11:16])
    plt.savefig('/media/drdarby/Elements/data/Thesis/LLC4320/animations/panels/eddy_points_rep_attr/eddy_'+str(i).zfill(3)+'.png')
    plt.close()
# Out:
#   0%|          | 0/232 [00:00<?, ?it/s]

# %%
plt.plot(lon_cs_rep_ed.isel(time=i),lat_cs_rep_ed.isel(time=i),'.',markersize=4,label='repelling points')
plt.plot(lon_cs_attr_ed.isel(time=i),lat_cs_attr_ed.isel(time=i),'.',markersize=4,label='attracting points')
plt.xlabel('Longitude')
plt.legend(loc='upper right')
plt.ylabel('Latitude')
plt.xticks(np.arange(-125.2, -123.5, step=0.2))
plt.yticks(np.arange(38.95, 40.3, step=0.30))
plt.title(str(np.array(lon_cs_rep_ed.isel(time=i).time))[:10]+' '+str(np.array(lon_cs_rep_ed.isel(time=i).time))[11:16])
# Out:
# Text(0.5, 1.0, '2012-08-31 18:00')

# %% [markdown]
# ### Case Study (filament)

# %%
cs_ridge_points_fil=ridge_points.sel(time=slice(case_study_range_fil[0],case_study_range_fil[1]))

# %%
fil_ridge_points=cs_ridge_points_fil.where(np.logical_and(ridge_points.isel(lon_lat=1)>40,ridge_points.isel(lon_lat=1)<42))
fil_ridge_points = fil_ridge_points.where(np.logical_and(ridge_points.isel(lon_lat=0)>-126.9,ridge_points.isel(lon_lat=0)<-123.5))

# %%
lon_cs_attr_fil = fil_ridge_points.isel(lon_lat=0)['attracting_structures'].dropna('points',how='all')
lat_cs_attr_fil = fil_ridge_points.isel(lon_lat=1)['attracting_structures'].dropna('points',how='all')
lon_cs_rep_fil = fil_ridge_points.isel(lon_lat=0)['repelling_structures'].dropna('points',how='all')
lat_cs_rep_fil = fil_ridge_points.isel(lon_lat=1)['repelling_structures'].dropna('points',how='all')

# %%
for i in tqdm(range(0,len(lon_cs_rep_fil))):
    plt.plot(lon_cs_attr_fil.isel(time=i),lat_cs_attr_fil.isel(time=i),'.',markersize=4,label='attracting points')
    plt.plot(lon_cs_rep_fil.isel(time=i),lat_cs_rep_fil.isel(time=i),'.',markersize=4, label='repelling points')
    plt.legend(loc='upper right')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')

    plt.ylim([40,42])
    plt.title(str(np.array(lon_cs_rep_fil.isel(time=i).time))[:10]+' '+str(np.array(lon_cs_rep_fil.isel(time=i).time))[11:16])
    plt.xlim([-126.9,-124])
    plt.savefig('/media/drdarby/Elements/data/Thesis/LLC4320/animations/panels/Filiment_points_rep/fil_'+str(i).zfill(3)+'.png')
    plt.close()
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]

# %%
i=0

plt.plot(lon_cs_attr_fil.isel(time=i),lat_cs_attr_fil.isel(time=i),'.',markersize=4)

plt.plot(lon_cs_rep_fil.isel(time=i),lat_cs_rep_fil.isel(time=i),'.',markersize=4)
#plt.ylim([40,42])
#plt.xlim([-126.9,-124])

plt.title(str(np.array(lon_cs_rep_fil.isel(time=i).time))[:10]+' '+str(np.array(lon_cs_rep_fil.isel(time=i).time))[11:16])


lon_sel = np.linspace(-126.2,-125.15,50)
lon_sel2 = np.linspace(-125.15,-124.4,50)
lon_sel3 = np.linspace(-126.625,-126,50)

y = ((40.9-40))*lon_sel+165.87-10-2.5

plt.plot(lon_sel,y,'r')
plt.plot(lon_sel3,y+.56,'r')
lon_sel4 = np.linspace(-126.5,-126)
y2 = (41.45-42)/(-126-(-127))*lon_sel4-28
plt.plot(lon_sel4[-1],y2[-1],'g.')

lon_sel5 = np.linspace(-126.5,-126.25, 30)
y3 = (42-y2[0])/(-126.25+126.5)*lon_sel5+256.63

lon_sel6 = np.linspace(-126.25,-125.5,40)

lon_sel7 = np.linspace(-125.5,-124.4,50)

y4 = (41.52-42)/(-124.4+125.5)*lon_sel7-12.76

plt.plot(lon_sel7[0],y4[0],'g.')
lat_sel = np.linspace(40.74,y4[-1],50,'r')
lon_sel8 = np.linspace(-126.625,-126.2,50)
y5 = (39.45-y[-1]+.56)/(-126.2+126.75)*lon_sel8-126.55

plt.plot(lon_sel8[-1],y5[-1],'g.')

plt.plot(lon_sel6[0],42,'b.')

plt.plot(lon_sel6,[42]*40,'r')
plt.plot(lon_sel5[0],y3[0],'g.')
plt.plot(lon_sel2,[40.74]*50,'r')
plt.plot([-124.4]*50,lat_sel,'r')

# %%
from shapely.geometry import Polygon
import shapely

points = [(lon_sel[0],y[0]),(lon_sel[-1],y[-1]),(lon_sel2[-1],40.74), (-124.4,lat_sel[-1]),(lon_sel6[-1],42),(lon_sel6[0],42),(lon_sel5[0],y3[0]),(lon_sel4[-1],y2[-1]),(lon_sel8[0],y5[0])]  # List of (x, y) coordinates
polygon = Polygon(points)

# %%
lat_fil_attr = lat_cs_attr_fil.isel(time=0).dropna(dim='points',how='all')
lon_fil_attr = lon_cs_attr_fil.isel(time=0).dropna(dim='points',how='all')
lat_fil_rep = lat_cs_rep_fil.isel(time=0).dropna(dim='points',how='all')
lon_fil_rep = lon_cs_rep_fil.isel(time=0).dropna(dim='points',how='all')
def listOfTuples(l1, l2):
    return list(map(lambda x, y:(x,y), l1, l2))

def contains_py(array, poly):
    return np.array([poly.contains(p) for p in ar

def points_in_poly(l1,l2,poly):
    points = listOfTuples(l1,l2)
    a = np.array([shapely.Point(i) for i in points], dtype=object)
    mask = contains_py(a,poly)
    l1_new = l1[mask]
    l2_new = l2[mask]
    return l1_new, l2_new



mask = contains_py(a,polygon)


lat_fil_study = lat_fil[mask]
lon_fil_study = lon_fil[mask]

plt.plot(lon_fil_study,lat_fil_study,'.')
plt.plot(x_polygon,y_polygon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       4 def listOfTuples(l1, l2):
#       5     return list(map(lambda x, y:(x,y), l1, l2))
# ----> 7 points = listOfTuples(lon_fil,lat_fil)
#       9 a = np.array([shapely.Point(i) for i in points], dtype=object)
#      13 def contains_py(array, poly):
#
# NameError: name 'lon_fil' is not defined

# %%
polygon

x_polygon,y_polygon = polygon.exterior.xy
plt.plot(lon_fil,lat_fil,'.')
plt.plot(x_polygon,y_polygon)

# %%
lat = np.array(lat_cs_attr_fil.dropna(dim)).ravel().round(8)
lon = np.array(lon_cs_attr_fil).ravel().round(8)

lat

#latlon = np.meshgrid(lon,lat)

#np.shape(np.unique(np.array(lat_cs_attr_fil).ravel().round(5)))
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %% [markdown]
# ### Properties of case studies

# %% [markdown]
# ### properties of filament

# %%
vort_lcs_files, vort_lcs_filepaths = tools.get_data_paths_from_binary(cutout_path,'vort_lcs',file_end='nc')
div_lcs_files, div_lcs_filepaths = tools.get_data_paths_from_binary(cutout_path,'div_lcs',file_end='nc')
strain_lcs_files, strain_lcs_filepaths = tools.get_data_paths_from_binary(cutout_path,'strain_lcs',file_end='nc')
vort_lcs = xr.open_mfdataset(vort_lcs_filepaths)
div_lcs = xr.open_mfdataset(div_lcs_filepaths)
strain_lcs = xr.open_mfdataset(strain_lcs_filepaths)

# %%
ridge_points_lon = ridge_points.isel(lon_lat=0).rename({'attracting_structures':'attracting_structures_lon','repelling_structures':'repelling_structures_lon'}).drop_vars('lon_lat')
ridge_points_lat = ridge_points.isel(lon_lat=1).rename({'attracting_structures':'attracting_structures_lat','repelling_structures':'repelling_structures_lat'}).drop_vars('lon_lat')

# %%
LCS_properties = xr.merge([ridge_points_lon,ridge_points_lat,strain_lcs,div_lcs,vort_lcs])

# %%
cs_properties_fil=LCS_properties.sel(time=slice(case_study_range_fil[0],case_study_range_fil[1]))
cs_properties_eddy=LCS_properties.sel(time=slice(case_study_range_eddy[0],case_study_range_eddy[1]))

# %%
fil_points_attr=cs_properties_fil.where(np.logical_and(cs_properties_fil['attracting_structures_lat']>40,cs_properties_fil['attracting_structures_lat']<42))
fil_points_attr =fil_points_attr.where(np.logical_and(cs_properties_fil['attracting_structures_lon']>-126.9,cs_properties_fil['attracting_structures_lon']<-123.5))

# %%
fil_points_rep=cs_properties_fil.where(np.logical_and(cs_properties_fil['repelling_structures_lat']>40,cs_properties_fil['repelling_structures_lat']<42))
fil_points_rep =fil_points_rep.where(np.logical_and(cs_properties_fil['repelling_structures_lon']>-126.9,cs_properties_fil['repelling_structures_lon']<-123.5))

# %%
fil_points_attr_n = fil_points_attr.dropna(dim='points',how='all').dropna(dim='time',how='all')
fil_points_rep_n = fil_points_rep.dropna(dim='points',how='all').dropna(dim='time',how='all')

# %%
fil_points_rep_n
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 56, points: 3115)
# Coordinates:
#   * points                     (points) int64 363 364 365 366 ... 3475 3476 3477
#   * time                       (time) datetime64[ns] 2012-08-06 ... 2012-08-1...
# Data variables:
#     attracting_structures_lon  (time, points) float64 nan nan nan ... nan nan
#     repelling_structures_lon   (time, points) float64 nan nan nan ... nan nan
#     attracting_structures_lat  (time, points) float64 nan nan nan ... nan nan
#     repelling_structures_lat   (time, points) float64 nan nan nan ... nan nan
#     strain_lcs_attr            (time, points) float64 dask.array<chunksize=(1, 3115), meta=np.ndarray>
#     strain_lcs_rep             (time, points) float64 dask.array<chunksize=(1, 3115), meta=np.ndarray>
#     div_lcs_attr               (time, points) float64 dask.array<chunksize=(1, 3115), meta=np.ndarray>
# ...

# %%
t=29#3 #20 #44
#plt.scatter(fil_points_attr_n['attracting_structures_lon'].isel(time=t),fil_points_attr_n['attracting_structures_lat'].dropna('time',how='all').isel(time=t),c=fil_points_attr_n['vort_lcs_attr'].dropna('time',how='all').isel(time=t),s=4,cmap=cmocean.cm.balance)
plt.scatter(fil_points_rep_n['repelling_structures_lon'].isel(time=t),fil_points_rep_n['repelling_structures_lat'].dropna('time',how='all').isel(time=t),c=fil_points_rep_n['vort_lcs_rep'].dropna('time',how='all').isel(time=t),s=4,cmap=cmocean.cm.balance)
#plt.colorbar(label='Vorticity (ALCS and RLCS points)')
plt.colorbar(label='Vorticity (RLCS points)')

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(str(np.array(fil_points_attr_n.time)[t])[0:13])
# Out:
# Text(0.5, 1.0, '2012-08-13T06')

# %%
fil_points_rep_n['strain_lcs_rep'].dropna('time',how='all').isel(time=16).dropna(dim='points',how='any').plot.hist(bins=30)
# Out:
# (array([ 5., 29., 41., 40., 57., 43., 62., 71., 60., 69., 66., 66., 46.,
#         52., 26., 31., 22., 26., 13., 11.,  9.,  8.,  5.,  3.,  1.,  2.,
#          4.,  1.,  3.,  2.]),
#  array([0.04391658, 0.14124342, 0.23857027, 0.33589711, 0.43322395,
#         0.5305508 , 0.62787764, 0.72520448, 0.82253133, 0.91985817,
#         1.01718501, 1.11451186, 1.2118387 , 1.30916554, 1.40649239,
#         1.50381923, 1.60114607, 1.69847292, 1.79579976, 1.8931266 ,
#         1.99045345, 2.08778029, 2.18510713, 2.28243398, 2.37976082,
#         2.47708766, 2.57441451, 2.67174135, 2.76906819, 2.86639504,
#         2.96372188]),
#  <BarContainer object of 30 artists>)

# %%
fil_points_attr_n = fil_points_attr_n.drop_vars(['strain_lcs_rep','repelling_structures_lon','repelling_structures_lat','div_lcs_rep','vort_lcs_rep'])
fil_points_rep_n = fil_points_rep_n.drop_vars(['strain_lcs_attr','attracting_structures_lon','attracting_structures_lat','div_lcs_attr','vort_lcs_attr'])

# %%
fil_points_rep_n.to_netcdf(cutout_path+'case_studies/fil/RLCS_fil_properties.nc')
fil_points_attr_n.to_netcdf(cutout_path+'case_studies/fil/ALCS_fil_properties.nc')

# %%
fil_points_attr_n
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 56, points: 7290)
# Coordinates:
#   * points                     (points) int64 1485 1486 1487 ... 8781 8782 8783
#   * time                       (time) datetime64[ns] 2012-08-06 ... 2012-08-1...
# Data variables:
#     attracting_structures_lon  (time, points) float64 nan nan nan ... nan nan
#     attracting_structures_lat  (time, points) float64 nan nan nan ... nan nan
#     strain_lcs_attr            (time, points) float64 dask.array<chunksize=(1, 7290), meta=np.ndarray>
#     div_lcs_attr               (time, points) float64 dask.array<chunksize=(1, 7290), meta=np.ndarray>
#     vort_lcs_attr              (time, points) float64 dask.array<chunksize=(1, 7290), meta=np.ndarray>

# %%
range_vort = np.linspace(-2,2.5,30)
range_div = np.linspace(-2.5,2.5,30)
range_strain = np.linspace(0,3.5,30)
for t in tqdm(np.arange(len(fil_points_rep_n.time))):
    vort_counts_attr,vort_vals_attr = np.histogram(fil_points_attr_n['vort_lcs_attr'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[-2,2.5])
    vort_counts_rep,vort_vals_rep = np.histogram(fil_points_rep_n['vort_lcs_rep'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[-2,2.5] )
    div_counts_attr,div_vals_attr = np.histogram(fil_points_attr_n['div_lcs_attr'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[-2.5,2.5])
    div_counts_rep,div_vals_rep = np.histogram(fil_points_rep_n['div_lcs_rep'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[-2.5,2.5] )
    strain_counts_attr,strain_vals_attr = np.histogram(fil_points_attr_n['strain_lcs_attr'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[0,3.5])
    strain_counts_rep,strain_vals_rep = np.histogram(fil_points_rep_n['strain_lcs_rep'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[0,3.5] )
    
    vort_counts_rep = np.reshape(vort_counts_rep,(1,30))
    vort_counts_attr = np.reshape(vort_counts_attr,(1,30))
    div_counts_rep = np.reshape(div_counts_rep,(1,30))
    div_counts_attr = np.reshape(div_counts_attr,(1,30))
    strain_counts_rep = np.reshape(strain_counts_rep,(1,30))
    strain_counts_attr = np.reshape(strain_counts_attr,(1,30))
    
    vort_counts_rep = xr.DataArray(vort_counts_rep,dims=['time','vort_values'],coords=[[np.array(fil_points_rep_n.time)[t]],range_vort],name='vort_dist_fil_rep')
    vort_counts_attr = xr.DataArray(vort_counts_attr,dims=['time','vort_values'],coords=[[np.array(fil_points_rep_n.time)[t]],range_vort],name='vort_dist_fil_attr')
    div_counts_rep = xr.DataArray(div_counts_rep,dims=['time','vort_values'],coords=[[np.array(fil_points_rep_n.time)[t]],range_div],name='div_dist_fil_rep')
    div_counts_attr = xr.DataArray(div_counts_attr,dims=['time','vort_values'],coords=[[np.array(fil_points_rep_n.time)[t]],range_div],name='div_dist_fil_attr')
    strain_counts_rep = xr.DataArray(strain_counts_rep,dims=['time','vort_values'],coords=[[np.array(fil_points_rep_n.time)[t]],range_strain],name='strain_dist_fil_rep')
    strain_counts_attr = xr.DataArray(strain_counts_attr,dims=['time','vort_values'],coords=[[np.array(fil_points_rep_n.time)[t]],range_strain],name='strain_dist_fil_attr')
    
    vort_counts_rep.to_netcdf(cutout_path+'case_studies/fil/distributions_vort/vort_counts_rep'+str(t).zfill(4)+'.nc')
    vort_counts_attr.to_netcdf(cutout_path+'case_studies/fil/distributions_vort/vort_counts_attr'+str(t).zfill(4)+'.nc')
    div_counts_rep.to_netcdf(cutout_path+'case_studies/fil/distributions_div/div_counts_rep'+str(t).zfill(4)+'.nc')
    div_counts_attr.to_netcdf(cutout_path+'case_studies/fil/distributions_div/div_counts_attr'+str(t).zfill(4)+'.nc')
    strain_counts_rep.to_netcdf(cutout_path+'case_studies/fil/distributions_strain/strain_counts_rep'+str(t).zfill(4)+'.nc')
    strain_counts_attr.to_netcdf(cutout_path+'case_studies/fil/distributions_strain/strain_counts_attr'+str(t).zfill(4)+'.nc')
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]

# %%
case_study_path = cutout_path+'case_studies/'

vort_fil_files, vort_fil_filepaths = tools.get_data_paths_from_binary(case_study_path,'fil/distributions_vort',file_end='nc')
div_fil_files, div_fil_filepaths = tools.get_data_paths_from_binary(case_study_path,'fil/distributions_div',file_end='nc')
strain_fil_files, strain_fil_filepaths = tools.get_data_paths_from_binary(case_study_path,'fil/distributions_strain',file_end='nc')
vort_fil_dist = xr.open_mfdataset(vort_fil_filepaths)
div_fil_dist = xr.open_mfdataset(div_fil_filepaths)
strain_fil_dist = xr.open_mfdataset(strain_fil_filepaths)

# %%
div_fil_dist
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 56, vort_values: 30)
# Coordinates:
#   * time               (time) datetime64[ns] 2012-08-06 ... 2012-08-19T18:00:00
#   * vort_values        (vort_values) float64 -2.5 -2.328 -2.155 ... 2.328 2.5
# Data variables:
#     div_dist_fil_attr  (time, vort_values) int64 dask.array<chunksize=(1, 30), meta=np.ndarray>
#     div_dist_fil_rep   (time, vort_values) int64 dask.array<chunksize=(1, 30), meta=np.ndarray>

# %%
total_vort_rep = vort_fil_dist['vort_dist_fil_rep'].sum(dim='vort_values')
total_vort_attr = vort_fil_dist['vort_dist_fil_attr'].sum(dim='vort_values')

# %%
# total_vort_rep = []
# total_vort_attr = []
# for l in range(0,30):
#     total_vort_rep.append()

# %%
total_div_rep = div_fil_dist['div_dist_fil_rep'].sum(dim='vort_values')
total_div_attr = div_fil_dist['div_dist_fil_attr'].sum(dim='vort_values')

# %%
total_strain_rep = strain_fil_dist['strain_dist_fil_rep'].sum(dim='vort_values')
total_strain_attr = strain_fil_dist['strain_dist_fil_attr'].sum(dim='vort_values')

# %%
(vort_fil_dist['vort_dist_fil_attr']/total_vort_attr).plot(x='time')
plt.title('Filament ALCS vorticity probability distributions')
# Out:
# Text(0.5, 1.0, 'Filament ALCS vorticity probability distributions')

# %%
(vort_fil_dist['vort_dist_fil_rep']/total_vort_rep).plot(x='time')
plt.title('Filament RLCS vorticity probability distributions')
# Out:
# Text(0.5, 1.0, 'Filament RLCS vorticity probability distributions')

# %%
(strain_fil_dist['strain_dist_fil_rep']/total_strain_rep).plot(x='time',vmax=.11)
plt.ylabel('strain_values')
# Out:
# Text(0, 0.5, 'strain_values')

# %%
(strain_fil_dist['strain_dist_fil_attr']/total_strain_attr).plot(x='time')
plt.ylabel('strain_values')
# Out:
# Text(0, 0.5, 'strain_values')

# %%
(div_fil_dist['div_dist_fil_attr']/total_div_attr).plot(x='time')
plt.ylabel('div_values')
# Out:
# Text(0, 0.5, 'div_values')

# %%
(div_fil_dist['div_dist_fil_rep']/total_div_attr).plot(x='time')
plt.ylabel('div_values')
# Out:
# Text(0, 0.5, 'div_values')

# %% [markdown]
# ### eddy properties

# %%
eddy_points_attr=cs_properties_eddy.where(np.logical_and(cs_properties_eddy['attracting_structures_lat']>38.8,cs_properties_eddy['attracting_structures_lat']<40.5))
eddy_points_attr =eddy_points_attr.where(np.logical_and(cs_properties_eddy['attracting_structures_lon']>-125.5,cs_properties_eddy['attracting_structures_lon']<-123.5))
eddy_points_rep=cs_properties_eddy.where(np.logical_and(cs_properties_eddy['repelling_structures_lat']>38.8,cs_properties_eddy['repelling_structures_lat']<40.5))
eddy_points_rep =eddy_points_rep.where(np.logical_and(cs_properties_eddy['repelling_structures_lon']>-125.5,cs_properties_eddy['repelling_structures_lon']<-123.5))


# plt.xticks(np.arange(-125.2, -123.5, step=0.2))
# plt.yticks(np.arange(38.95, 40.3, step=0.30))

# %%
eddy_points_attr_n = eddy_points_attr.dropna(dim='points',how='all').dropna(dim='time',how='all')
eddy_points_rep_n = eddy_points_rep.dropna(dim='points',how='all').dropna(dim='time',how='all')

# %%
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 232, points: 2071)
# Coordinates:
#   * points                     (points) int64 169 173 174 175 ... 2241 2242 2243
#   * time                       (time) datetime64[ns] 2012-07-05 ... 2012-08-3...
# Data variables:
#     attracting_structures_lon  (time, points) float64 nan nan nan ... nan nan
#     repelling_structures_lon   (time, points) float64 nan nan nan ... nan nan
#     attracting_structures_lat  (time, points) float64 nan nan nan ... nan nan
#     repelling_structures_lat   (time, points) float64 nan nan nan ... nan nan
#     strain_lcs_attr            (time, points) float64 dask.array<chunksize=(1, 2071), meta=np.ndarray>
#     strain_lcs_rep             (time, points) float64 dask.array<chunksize=(1, 2071), meta=np.ndarray>
#     div_lcs_attr               (time, points) float64 dask.array<chunksize=(1, 2071), meta=np.ndarray>
# ...

# %%
eddy_points_attr_n = eddy_points_attr_n.drop_vars(['strain_lcs_rep','repelling_structures_lon','repelling_structures_lat','div_lcs_rep','vort_lcs_rep'])
eddy_points_rep_n = eddy_points_rep_n.drop_vars(['strain_lcs_attr','attracting_structures_lon','attracting_structures_lat','div_lcs_attr','vort_lcs_attr'])

# %%
# eddy_points_rep_n.to_netcdf(cutout_path+'case_studies/eddy/RLCS_fil_properties.nc')
# eddy_points_attr_n.to_netcdf(cutout_path+'case_studies/eddy/ALCS_fil_properties.nc')

# %%
eddy_points_rep_n
# Out:
# <xarray.Dataset>
# Dimensions:                   (time: 232, points: 2071)
# Coordinates:
#   * points                    (points) int64 169 173 174 175 ... 2241 2242 2243
#   * time                      (time) datetime64[ns] 2012-07-05 ... 2012-08-31...
# Data variables:
#     repelling_structures_lon  (time, points) float64 nan nan nan ... nan nan nan
#     repelling_structures_lat  (time, points) float64 nan nan nan ... nan nan nan
#     strain_lcs_rep            (time, points) float64 dask.array<chunksize=(1, 2071), meta=np.ndarray>
#     div_lcs_rep               (time, points) float64 dask.array<chunksize=(1, 2071), meta=np.ndarray>
#     vort_lcs_rep              (time, points) float64 dask.array<chunksize=(1, 2071), meta=np.ndarray>

# %%
t=146
plt.scatter(eddy_points_attr_n['attracting_structures_lon'].isel(time=t),eddy_points_attr_n['attracting_structures_lat'].dropna('time',how='all').isel(time=t),c=eddy_points_attr_n['vort_lcs_attr'].dropna('time',how='all').isel(time=t),s=4,cmap=cmocean.cm.balance,vmin=-2)
plt.scatter(eddy_points_rep_n['repelling_structures_lon'].isel(time=t),eddy_points_rep_n['repelling_structures_lat'].isel(time=t),c=eddy_points_rep_n['vort_lcs_rep'].dropna('time',how='all').isel(time=t),s=4,cmap=cmocean.cm.balance,vmin=-2)
#plt.colorbar(label='Vorticity (ALCS and RLCS points)')
plt.colorbar(label='Vorticity (ALCS and RLCS points)')
plt.xticks(rotation=45)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(str(np.array(eddy_points_attr_n.time)[t])[0:13])
# Out:
# Text(0.5, 1.0, '2012-08-10T12')

# %%
range_vort = np.linspace(-2,2.5,30)
range_div = np.linspace(-2.5,2.5,30)
range_strain = np.linspace(0,3.5,30)
for t in tqdm(np.arange(len(eddy_points_attr_n.time))):
    vort_counts_attr,vort_vals_attr = np.histogram(eddy_points_attr_n['vort_lcs_attr'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[-2,2.5])
    vort_counts_rep,vort_vals_rep = np.histogram(eddy_points_rep_n['vort_lcs_rep'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[-2,2.5] )
    div_counts_attr,div_vals_attr = np.histogram(eddy_points_attr_n['div_lcs_attr'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[-2.5,2.5])
    div_counts_rep,div_vals_rep = np.histogram(eddy_points_rep_n['div_lcs_rep'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[-2.5,2.5] )
    strain_counts_attr,strain_vals_attr = np.histogram(eddy_points_attr_n['strain_lcs_attr'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[0,3.5])
    strain_counts_rep,strain_vals_rep = np.histogram(eddy_points_rep_n['strain_lcs_rep'].isel(time=t).dropna(dim='points',how='any'),bins=30,range=[0,3.5] )
    
    vort_counts_rep = np.reshape(vort_counts_rep,(1,30))
    vort_counts_attr = np.reshape(vort_counts_attr,(1,30))
    div_counts_rep = np.reshape(div_counts_rep,(1,30))
    div_counts_attr = np.reshape(div_counts_attr,(1,30))
    strain_counts_rep = np.reshape(strain_counts_rep,(1,30))
    strain_counts_attr = np.reshape(strain_counts_attr,(1,30))
    
    vort_counts_rep = xr.DataArray(vort_counts_rep,dims=['time','vort_values'],coords=[[np.array(eddy_points_rep_n.time)[t]],range_vort],name='vort_dist_eddy_rep')
    vort_counts_attr = xr.DataArray(vort_counts_attr,dims=['time','vort_values'],coords=[[np.array(eddy_points_rep_n.time)[t]],range_vort],name='vort_dist_eddy_attr')
    div_counts_rep = xr.DataArray(div_counts_rep,dims=['time','div_values'],coords=[[np.array(eddy_points_rep_n.time)[t]],range_div],name='div_dist_eddy_rep')
    div_counts_attr = xr.DataArray(div_counts_attr,dims=['time','div_values'],coords=[[np.array(eddy_points_rep_n.time)[t]],range_div],name='div_dist_eddy_attr')
    strain_counts_rep = xr.DataArray(strain_counts_rep,dims=['time','strain_values'],coords=[[np.array(eddy_points_rep_n.time)[t]],range_strain],name='strain_dist_eddy_rep')
    strain_counts_attr = xr.DataArray(strain_counts_attr,dims=['time','strain_values'],coords=[[np.array(eddy_points_rep_n.time)[t]],range_strain],name='strain_dist_eddy_attr')
    
    vort_counts_rep.to_netcdf(cutout_path+'case_studies/eddy/distributions_vort/vort_counts_rep'+str(t).zfill(4)+'.nc')
    vort_counts_attr.to_netcdf(cutout_path+'case_studies/eddy/distributions_vort/vort_counts_attr'+str(t).zfill(4)+'.nc')
    div_counts_rep.to_netcdf(cutout_path+'case_studies/eddy/distributions_div/div_counts_rep'+str(t).zfill(4)+'.nc')
    div_counts_attr.to_netcdf(cutout_path+'case_studies/eddy/distributions_div/div_counts_attr'+str(t).zfill(4)+'.nc')
    strain_counts_rep.to_netcdf(cutout_path+'case_studies/eddy/distributions_strain/strain_counts_rep'+str(t).zfill(4)+'.nc')
    strain_counts_attr.to_netcdf(cutout_path+'case_studies/eddy/distributions_strain/strain_counts_attr'+str(t).zfill(4)+'.nc')
# Out:
#   0%|          | 0/232 [00:00<?, ?it/s]

# %%
vort_eddy_files, vort_eddy_filepaths = tools.get_data_paths_from_binary(case_study_path,'eddy/distributions_vort',file_end='nc')
div_eddy_files, div_eddy_filepaths = tools.get_data_paths_from_binary(case_study_path,'eddy/distributions_div',file_end='nc')
strain_eddy_files, strain_eddy_filepaths = tools.get_data_paths_from_binary(case_study_path,'eddy/distributions_strain',file_end='nc')
vort_eddy_dist = xr.open_mfdataset(vort_eddy_filepaths)
div_eddy_dist = xr.open_mfdataset(div_eddy_filepaths)
strain_eddy_dist = xr.open_mfdataset(strain_eddy_filepaths)

# %%
total_vort_rep = vort_eddy_dist['vort_dist_eddy_rep'].sum(dim='vort_values')
total_vort_attr = vort_eddy_dist['vort_dist_eddy_attr'].sum(dim='vort_values')
total_div_rep = div_eddy_dist['div_dist_eddy_rep'].sum(dim='div_values')
total_div_attr = div_eddy_dist['div_dist_eddy_attr'].sum(dim='div_values')
total_strain_rep = strain_eddy_dist['strain_dist_eddy_rep'].sum(dim='strain_values')
total_strain_attr = strain_eddy_dist['strain_dist_eddy_attr'].sum(dim='strain_values')

# %%
(vort_eddy_dist['vort_dist_eddy_rep']/total_vort_rep).sel(time=slice('2012-08-06','2012-08-14')).plot(x='time')
plt.title('Eddy RLCS vorticity probability distributions')
# Out:
# Text(0.5, 1.0, 'Eddy RLCS vorticity probability distributions')

# %%
(vort_eddy_dist['vort_dist_eddy_attr']/total_vort_attr).plot(x='time')
plt.title('Eddy ALCS vorticity probability distributions')
# Out:
# Text(0.5, 1.0, 'Eddy ALCS vorticity probability distributions')

# %%
(strain_eddy_dist['strain_dist_eddy_rep']).plot(x='time')

# %%
(vort_eddy_dist['vort_dist_eddy_attr']).plot(x='time')

# %%
(strain_eddy_dist['strain_dist_eddy_attr']).plot(x='time')

# %% [markdown]
# ### Wind stress relation to filaments

# %%
cutout_path = '/media/drdarby/Elements/data/Thesis/LLC4320/nc_files/cutouts/'

# %%
tauxy = xr.open_dataset(cutout_path+'tau_cape_mend.nc')

# %%
tauxy = tauxy.isel(k=0)

# %%
tauxy = tauxy.sel(time=slice(case_study_range_eddy[0],case_study_range_eddy[1]))

# %%
tauxy
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1392, i: 237, j: 216)
# Coordinates:
#   * time     (time) datetime64[ns] 2012-07-05 2012-07-05 ... 2012-08-31
#   * i        (i) int64 656 657 658 659 660 661 662 ... 887 888 889 890 891 892
#   * j        (j) int64 211 212 213 214 215 216 217 ... 421 422 423 424 425 426
#     XC       (i, j) float32 ...
#     YC       (i, j) float32 ...
#     k        int64 0
# Data variables: (12/14)
#     oceTAUX  (time, i, j) float32 ...
#     oceTAUY  (time, i, j) float32 ...
#     DXC      (i, j) float32 ...
#     DXG      (i, j) float32 ...
#     DXV      (i, j) float32 ...
#     DYC      (i, j) float32 ...
#     ...       ...
#     Depth    (i, j) float32 ...
#     RAC      (i, j) float32 ...
#     RAZ      (i, j) float32 ...
#     XG       (i, j) float32 ...
#     YG       (i, j) float32 ...
#     hFacC    (i, j) float32 ...

# %%
tauxy['oceTAUX'].sel(time='2012-08-10').isel(time=0).plot()

# %%
tauxy['oceTAUY'].sel(time='2012-08-09').isel(time=0).plot()

# %%
#wind stress curl <--> w fields
#+ direction of filament

# %% [markdown]
# ### SSH to filament and eddy

# %%
lcs_land_nan = xr.open_dataset('/media/drdarby/Elements/data/Thesis/LLC4320/nc_files/cutouts/lcs_cape_mend_landmask.nc')

# %%
lcs_land_nan
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1519, lat: 236, lon: 215)
# Coordinates:
#   * time     (time) datetime64[ns] 2011-11-01 ... 2012-11-14T12:00:00
#   * lat      (lat) float64 38.51 38.52 38.54 38.55 ... 41.89 41.9 41.92 41.93
#   * lon      (lon) float64 -127.6 -127.6 -127.6 -127.5 ... -123.2 -123.2 -123.2
# Data variables:
#     ALCS     (time, lat, lon) float64 ...
#     RLCS     (time, lat, lon) float64 ...

# %%
eta = xr.open_dataset(path_tohd + 'cutouts/ssh_cape_mend_unfilt.nc')
eta = eta['Eta'][:,:-1,:-1]

# %%
fil_points_rep_n = xr.open_dataset(cutout_path+'case_studies/fil/RLCS_fil_properties.nc')
fil_points_attr_n = xr.open_dataset(cutout_path+'case_studies/fil/ALCS_fil_properties.nc')

# %%
eddy_points_rep_n = xr.open_dataset(cutout_path+'case_studies/eddy/RLCS_fil_properties.nc')
eddy_points_attr_n = xr.open_dataset(cutout_path+'case_studies/eddy/ALCS_fil_properties.nc')

# %%
eta_filt = tools.filt(eta.sel(time=slice(case_study_range_eddy[0],case_study_range_eddy[1])),T=33)
eta_filt = tools.filt(eta_filt,T=15)

# %%
eta_filt['i'] = np.array(lcs_land_nan.lat)
eta_filt['j'] = np.array(lcs_land_nan.lon)
eta_filt = eta_filt.rename({'i':'lat','j':'lon'})

# %%
eddy_lon_rep = eddy_points_rep_n.sel(time='2012-08-12').isel(time=2)['repelling_structures_lon']
eddy_lat_rep = eddy_points_rep_n.sel(time='2012-08-12').isel(time=2)['repelling_structures_lat']
fil_lon_rep = fil_points_rep_n.sel(time='2012-08-12').isel(time=2)['repelling_structures_lon']
fil_lat_rep = fil_points_rep_n.sel(time='2012-08-12').isel(time=2)['repelling_structures_lat']

# %%
eddy_lon_attr = eddy_points_attr_n.sel(time='2012-08-12').isel(time=2)['attracting_structures_lon']
eddy_lat_attr = eddy_points_attr_n.sel(time='2012-08-12').isel(time=2)['attracting_structures_lat']
fil_lon_attr = fil_points_attr_n.sel(time='2012-08-12').isel(time=2)['attracting_structures_lon']
fil_lat_attr = fil_points_attr_n.sel(time='2012-08-12').isel(time=2)['attracting_structures_lat']

# %%
eta_filt.sel(time='2012-08-12').isel(time=12).plot.contour(levels=np.linspace(0.1,0.6,20),cmap=cmocean.cm.gray_r,add_colorbar=True)
plt.scatter(eddy_lon_attr,eddy_lat_attr,s=5,label='ALCS')
plt.scatter(eddy_lon_rep,eddy_lat_rep,s=5,label='RLCS')
plt.legend()

# %%
eta_filt.sel(time='2012-08-12').isel(time=12).plot.contour(levels=np.linspace(0.1,0.6,20),cmap=cmocean.cm.gray_r,add_colorbar=True)
plt.scatter(fil_lon_attr,fil_lat_attr,label='ALCS',s=5)
plt.scatter(fil_lon_rep,fil_lat_rep,label='RLCS',s=5)
plt.legend()
#plt.xlim([-127,-124])
#plt.ylim([39.9,42])

# %%
total_lon_attr = ridge_points_lon['attracting_structures_lon'].sel(time='2012-08-12').isel(time=2)
total_lat_attr = ridge_points_lat['attracting_structures_lat'].sel(time='2012-08-12').isel(time=2)
total_lon_rep = ridge_points_lon['repelling_structures_lon'].sel(time='2012-08-12').isel(time=2)
total_lat_rep = ridge_points_lat['repelling_structures_lat'].sel(time='2012-08-12').isel(time=2)

# %%
eta_filt.sel(time='2012-08-12').isel(time=12).plot.contour(levels=np.linspace(0.1,0.6,20),cmap=cmocean.cm.gray_r,add_colorbar=True)
plt.scatter(total_lon_attr,total_lat_attr,label='ALCS',s=5)
plt.scatter(total_lon_rep,total_lat_rep,label='RLCS',s=5)
plt.legend()
