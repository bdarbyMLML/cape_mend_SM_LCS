# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import math
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import datetime as dt
# %matplotlib inline
import os
import sys
from tqdm import tqdm
sys.path.append('/home/drdarby/Desktop/cape_mend_SM_LCS/datatools')
from datatools import datatools as tools
from scipy.fft import fft, fftfreq
from scipy.signal import periodogram
from scipy.signal import welch
from scipy.stats import chi2
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.readers import reader_global_landmask
import opendrift.readers as readers
from opendrift.models.oceandrift import OceanDrift
from datetime import timedelta
from scipy.interpolate import griddata

# %%
hfr_files, hfr_filepaths = tools.get_data_paths_from_binary('/media/basil/Elements/data/Thesis/HFR/','nc_files',file_end='nc')
hfr = xr.open_mfdataset(hfr_filepaths)

# %%
path_tohd = '/media/basil/Elements/data/Thesis/LLC4320/nc_files/'

model_uv = xr.open_dataset(path_tohd + 'cutouts/uv_cape_mend_llc4320.nc').isel(k=0)
lcs_model = xr.open_dataset('/media/basil/Elements/data/Thesis/LLC4320/nc_files/cutouts/lcs_cape_mend_landmask.nc')

# %%
u_model = model_uv.sel(time='2012-01-01').isel(time=4)['u'].where(model_uv.lon>-126)
v_model = model_uv.sel(time='2012-01-01').isel(time=4)['v'].where(model_uv.lon>-126)

# %%
finite_values = np.isfinite(hfr['u'])
spatial_var = finite_values.sum(dim={'time'})/len(finite_values.time)

spatial_var = spatial_var.where(spatial_var != 0)
#masks_greater90 = spatial_var.where(((spatial_var>.85)))
tools.map_capemend(spatial_var*100, labelz = 'Data avalibilty %')
#(spatial_var*100).plot(alpha=.75,cbar_kwargs={'label':'Data avalibilty %'})
# plt.xlim(-127,-123)
# plt.ylim(38,42)

# %%
o = OceanDrift(loglevel=50) # Setting the log level will give the user different amounts of info (0=Debug (all), 20=Minimum, 50=None)
o_diffusion = OceanDrift(loglevel=50) # Setting the log level will give the user different amounts of info (0=Debug (all), 20=Minimum, 50=None)
o.set_config('general:coastline_action', 'previous') 
o.set_config('drift:advection_scheme', 'runge-kutta4')
o.set_config('general:time_step_minutes', 60)
o.set_config('drift:stokes_drift', False)
#o.set_config('seed:ocean_only', True)
o.set_config('general:use_auto_landmask', False)
#o.set_config('environment:fallback:land_binary_mask', 1)
o_diffusion.set_config('general:coastline_action', 'stranding') 
o_diffusion.set_config('drift:advection_scheme', 'runge-kutta4')
o_diffusion.set_config('general:time_step_minutes', 60)
o_diffusion.set_config('drift:stokes_drift', False)
o_diffusion.set_config('drift:current_uncertainty_uniform', 0)
o_diffusion.set_config('general:use_auto_landmask', False)
reader_data = reader_netCDF_CF_generic.Reader(hfr)
reader_landmask = reader_global_landmask.Reader()
#reader_landmask.activate_environment_mapping('land_binary_mask_from_ocean_depth')
#reader_data.activate_environment_mapping('land_binary_mask_from_ocean_depth')
o.add_reader([reader_data,reader_landmask])
o_diffusion.add_reader([reader_data,reader_landmask])

# %%
lcs = o.calculate_ftle( 
    time=reader_data.start_time + timedelta(hours=0),
    time_step=timedelta(minutes=30),
    duration=timedelta(hours=12), delta_x=0.06246948,delta_y=.05393982,reader=reader_data,
    RLCS=True)

# %%
lcs_lat = lcs['lat']
lcs_lon = lcs['lon']
alcs_time = lcs['time']
alcs_data = lcs['ALCS'].data
time = alcs_time
lat = lcs_lat[:,0]
lon = lcs_lon[0,:]
rlcs_data = lcs['RLCS'].data

ALCS = xr.DataArray(alcs_data, coords = [time,lat,lon],dims = ['time','lat','lon'],name='ALCS')
RLCS = xr.DataArray(rlcs_data, coords = [time,lat,lon],dims = ['time','lat','lon'],name='RLCS')

# %%
lcs_model['ALCS'].sel(lon=slice(-125,-124),time='2012-01-01')
# Out:
# <xarray.DataArray 'ALCS' (time: 4, lat: 236, lon: 48)>
# [45312 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 2012-01-01 ... 2012-01-01T18:00:00
#   * lat      (lat) float64 38.51 38.52 38.54 38.55 ... 41.89 41.9 41.92 41.93
#   * lon      (lon) float64 -125.0 -125.0 -124.9 -124.9 ... -124.1 -124.0 -124.0

# %%
#hfr.isel(time=0)['u'].plot()
fig,ax = plt.subplots(ncols=2, nrows=1,figsize=(10,4),sharex=True,sharey=True,)


FTLE_threshold = [1e-6,5e-5] #Attracting


tools.map_capemend(hfr.sel(lat=slice(38.5,42)).isel(time=4)['u'],hfr.sel(lat=slice(38.5,42)).isel(time=4)['v'],ALCS.isel(time=0).where(np.array(np.isfinite(hfr['u'].isel(time=4)[:,:-1]))).sel(lat=slice(38.5,42)), scl=10,zmin = FTLE_threshold[0],zmax=FTLE_threshold[1],colorstyle='turbo',labelz = 'Observed ALCS')
plt.show()
tools.map_capemend(u_model[::4,::4],v_model[::4,::4],lcs_model['ALCS'].sel(lon=slice(-126,-123),time='2012-01-01').isel(time=0), scl=10,zmin = FTLE_threshold[0],zmax=FTLE_threshold[1],colorstyle='turbo',labelz = 'Model ALCS')

# %%
# Out:
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:22 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:23 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:24 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:25 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:26 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:27 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:29 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:30 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:31 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:32 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:33 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!
# 12:05:34 WARNING opendrift:133: Still NaN-values after 10 iterations, exiting!

# %%
# file_6km = "http://hfrnet-tds.ucsd.edu/thredds/dodsC/HFR/USWC/6km/hourly/RTV/HFRADAR_US_West_Coast_6km_Resolution_Hourly_RTV_best.ncd"
# #file_6km = 'https://dods.ndbc.noaa.gov/thredds/dodsC/hfradar_uswc_6km'
# #file_6km = 'https://dods.ndbc.noaa.gov/thredds/dodsC/hfradar_uswc_6km'
# #ds_2km = xr.open_dataset(file_2km, decode_coords=True, decode_times=True)
# ds_6km = xr.open_dataset(file_6km)

# %%
#lcs_files, lcs_filepaths = tools.get_data_paths_from_binary('/media/basil/Elements/data/Thesis/LLC4320/','LCS_data_nc',file_end='nc')
lcs_model = xr.open_dataset('/media/basil/Elements/data/Thesis/LLC4320/nc_files/cutouts/lcs_cape_mend_landmask.nc')
lcs_model['ALCS']
# Out:
# <xarray.DataArray 'ALCS' (time: 1519, lat: 236, lon: 215)>
# [77074060 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 2011-11-01 ... 2012-11-14T12:00:00
#   * lat      (lat) float64 38.51 38.52 38.54 38.55 ... 41.89 41.9 41.92 41.93
#   * lon      (lon) float64 -127.6 -127.6 -127.6 -127.5 ... -123.2 -123.2 -123.2

# %%
lcs

# %%
# ds_cut = ds_6km.sel(lat=slice(38.0,42.0),time=slice('2011-01-01','2012-12-01'))

# %%
# path_tohd = '/media/drdarby/Elements/data/Thesis/HFR/nc_files/'

# %%
# file = 'cape_mend_hfr_llc'

# %%
# for i in range(0,12):
#     month = ds_cut.sel(time='2012-'+str(i+1))
#     month.to_netcdf(path_tohd+file+str(i+1)+'.nc')
