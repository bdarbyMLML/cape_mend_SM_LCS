# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import requests  # HTTP library for Python
import bs4
import math
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import gsw
# %matplotlib inline
import os
import sys
import xmitgcm 
import xgcm
import pyproj
#import wget
#sys.path.append('../../ECCOv4-py/ECCOv4-py')
#import ecco_v4_py as ecco
import cmocean
sys.path.append('/home/basil/Desktop/cape_mend_SM_LCS/datatools')
from datatools import datatools as tools
#from moviepy.config import change_settings
#change_settings({"FFMPEG_BINARY": "/usr/bin/ffmpeg"})
#import moviepy.video.io.ImageSequenceClip 

from scipy.fft import fft, fftfreq
from scipy.signal import periodogram
from scipy.signal import welch
from scipy.stats import chi2
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.readers import reader_global_landmask
import opendrift.readers as readers
from opendrift.models.oceandrift import OceanDrift
from datetime import timedelta
from scipy.interpolate import griddata
from tqdm.notebook import tqdm

# %%
path_obs = '/media/basil/Elements/data/Thesis/gliders/cruise/swfscTrinidadCTD_5993_df58_8d33.nc'
data_obs = xr.open_dataset(path_obs)

# %%
(-124.75783333-.5, -124.20275+.5) 
(41.0537-.5, 41.06663333+.5)
# Out:
# (40.5537, 41.56663333)

# %%
plt.plot(data_obs['longitude'].isel(profile=0),data_obs['latitude'].isel(profile=0))

# %%
lat_max = data_obs.latitude.max()
lon_max = data_obs.longitude.max()-360
lat_min = data_obs.latitude.min()
lon_min = data_obs.longitude.min()-360

box = [lon_min,lat_min,lon_max,lat_max]
box
# Out:
# [<xarray.DataArray 'longitude' ()>
#  array(-124.75783333),
#  <xarray.DataArray 'latitude' ()>
#  array(41.0537),
#  <xarray.DataArray 'longitude' ()>
#  array(-124.20275),
#  <xarray.DataArray 'latitude' ()>
#  array(41.06663333)]

# %%
data_obs
# Out:
# <xarray.Dataset>
# Dimensions:                 (trajectory: 17, profile: 6, obs: 490)
# Coordinates:
#     time                    (trajectory, profile) datetime64[ns] ...
#     latitude                (trajectory, profile) float64 41.06 41.06 ... nan
#     longitude               (trajectory, profile) float64 235.7 235.6 ... nan
#     depth                   (trajectory, profile, obs) float64 ...
# Dimensions without coordinates: trajectory, profile, obs
# Data variables: (12/17)
#     cruise_name             (trajectory) object ...
#     ship_name               (trajectory) object ...
#     station                 (trajectory, profile) float64 ...
#     station_name            (trajectory, profile) object ...
#     temperature             (trajectory, profile, obs) float64 ...
#     temperature_calib_flag  (trajectory, profile, obs) float64 ...
#     ...                      ...
#     chla_calib              (trajectory, profile, obs) float64 ...
#     dissolved_oxygen        (trajectory, profile, obs) float64 ...
#     pH                      (trajectory, profile, obs) float64 ...
#     PAR                     (trajectory, profile, obs) float64 ...
#     beam_attenuation        (trajectory, profile, obs) float64 ...
#     transmissivity          (trajectory, profile, obs) float64 ...
# Attributes: (12/40)
#     cdm_data_type:                 TrajectoryProfile
#     cdm_profile_variables:         time,station,station_name,latitude,longitude
#     cdm_trajectory_variables:      cruise_name,ship_name
#     Conventions:                   CF-1.6, ACDD-1.3, COARDS
#     creator_email:                 eric.bjorkstedt@noaa.gov
#     creator_name:                  Eric P. Bjorkstedt
#     ...                            ...
#     subsetVariables:               time,station,station_name,cruise_name,ship...
#     summary:                       Hydrographic data from conductivity-temper...
#     time_coverage_end:             2012-11-27T03:16:11Z
#     time_coverage_start:           2011-11-16T03:12:42Z
#     title:                         Trinidad Head Line CTD Hydrography
#     Westernmost_Easting:           235.24216666666666
